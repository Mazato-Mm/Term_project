# %%
#Sys_เลือกโหมด
word_dict = {
    "easy": [
        "apple", "house", "music", "plant", "stone",
        "river", "light", "water", "bread", "smile",
        "chair", "table", "mouse", "clock", "phone",
        "green", "black", "white", "happy", "sweet",
        "flower", "heart", "shirt", "pencil", "cloud"
    ],
    "hard": [
        "castle", "ocean", "jungle", "forest", "mystery",
        "diamond", "planet", "ancient", "puzzle", "crystal",
        "galaxy", "kingdom", "marble", "monster", "kingpin",
        "treasure", "village", "capital", "kingdom", "sphinx",
        "labyrinth", "alchemy", "sculptor", "voyager", "ceremony"
    ]
}


class ModeSelector:
    def __init__(self, surface, word_dict):
        self.surface = surface
        self.word_dict = word_dict
        self.buttons = [
            Button("Easy", 150, 150, 200, 60, BLUE),
            Button("Hard", 150, 250, 200, 60, GREEN)
        ]
